# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the content",
    metadata={
        "source": "example.txt",
        "pages": 1,
        "author": "Jansen"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Jansen'}, page_content='this is the content')

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('../data/text_files/python.txt', encoding='utf-8')
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python.txt'}, page_content='Python is a versatile, high-level, and beginner-friendly programming language used for web development, software, data science, and automation. Its simple, readable syntax makes it easy to learn, while its extensive libraries and frameworks allow for a wide range of applications, from simple scripts to complex machine learning models.  \n\nKey characteristics\n- High-level and interpreted: Python has a high level of abstraction from hardware and is interpreted, meaning code is executed line by line without a prior compilation step, which speeds up the edit-test-debug cycle. \n- Easy to learn: It is known for its clear, readable syntax that emphasizes code clarity, making it an excellent choice for beginners. \n- General-purpose: Python is not limited to a single type of problem and can be used for a wide variety of applications. \n- Versatile: It is used in many fields, including web development, software development, mathematics, data analysis, and artificial intelligence. \n- Object-oriented: While it can be used for procedural and functional applications, Python is fundamentally an object-oriented language. \n- Cross-platform: Python software is free to download and can run on different operating systems. \n\nCommon uses\n- Web development: Building server-side applications.\n- Automation: Writing scripts to automate repetitive tasks.\n- Data science and machine learning: Performing complex mathematics, data analysis, and building AI models.\n- Software development: Creating applications and rapid prototyping. ')]

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    '../data/text_files',
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=True
)

documents=dir_loader.load()
documents
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 235.95it/s]
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine learning is a subfield of artificial intelligence (AI) that uses algorithms to enable computers to learn from data and improve over time without being explicitly programmed. Instead of following hard-coded instructions, systems use algorithms to find patterns in data, make predictions, and perform tasks like classifying information or suggesting products based on past behavior. \n\nHow it works\n- Training: A model is "trained" on a large dataset that is similar to the real-world problem it needs to solve. For example, a model can be trained on thousands of pictures labeled "cat" or "truck".\n- Learning patterns: The algorithm learns to recognize the key features or patterns that distinguish between different categories, such as the features that make up a cat versus a truck.\n- Generalization: Once trained, the model can then apply what it learned to new, unseen data to make accurate predictions or decisions. For instance, it can identify a cat in a photo it has never seen before. \n\nKey applications\n -Personalized recommendations: Suggesting products on an e-commerce site or movies on a streaming platform based on user history.\n- Fraud detection: Identifying unusual activity in financial transactions that could indicate fraud.\n- Image and speech recognition: Enabling features like facial recognition on a phone or voice assistants to understand commands.\n- Healthcare: Analyzing patient data to help with diagnostics or personalizing treatments.\n- Autonomous vehicles: Using data from cameras and sensors to help a car learn to navigate, steer, and brake safely. '),
#  Document(metadata={'source': '..\\data\\text_files\\python.txt'}, page_content='Python is a versatile, high-level, and beginner-friendly programming language used for web development, software, data science, and automation. Its simple, readable syntax makes it easy to learn, while its extensive libraries and frameworks allow for a wide range of applications, from simple scripts to complex machine learning models.  \n\nKey characteristics\n- High-level and interpreted: Python has a high level of abstraction from hardware and is interpreted, meaning code is executed line by line without a prior compilation step, which speeds up the edit-test-debug cycle. \n- Easy to learn: It is known for its clear, readable syntax that emphasizes code clarity, making it an excellent choice for beginners. \n- General-purpose: Python is not limited to a single type of problem and can be used for a wide variety of applications. \n- Versatile: It is used in many fields, including web development, software development, mathematics, data analysis, and artificial intelligence. \n- Object-oriented: While it can be used for procedural and functional applications, Python is fundamentally an object-oriented language. \n- Cross-platform: Python software is free to download and can run on different operating systems. \n\nCommon uses\n- Web development: Building server-side applications.\n- Automation: Writing scripts to automate repetitive tasks.\n- Data science and machine learning: Performing complex mathematics, data analysis, and building AI models.\n- Software development: Creating applications and rapid prototyping. ')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader = DirectoryLoader(
    '../data/pdf_files',
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=True
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 161.04it/s]
# [Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-11-04T18:57:35+00:00', 'source': '..\\data\\pdf_files\\Arcega_CV.pdf', 'file_path': '..\\data\\pdf_files\\Arcega_CV.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Arcega_CV', 'author': 'Lance Angelo Arcega', 'subject': '', 'keywords': 'DAG3vzieRD8,BAEa-_UscSk,0', 'moddate': '2025-11-04T18:57:35+00:00', 'trapped': '', 'modDate': "D:20251104185735+00'00'", 'creationDate': "D:20251104185735+00'00'", 'page': 0}, page_content='LANCE ANGELO P ARCEGA\nKEY SKILLS\nProgramming Languages (Java,\nJS, Python, MySQL)\nData Analysis\nOrganizational and time\nmanagement skills. \nProblem-solving.\nTeam Management/Service\nAttention to details\nMicrosoft 365\nEDUCATION\nAug 2022 - Present\nBachelor of Science in Computer Science\nAngeles University Foundation\nSpecialization in Data Science\nCollege Scholar\nPROJECTS\nJan 2025 - Dec 2025\nRice Production Prediction using RF+GPR Hybrid\nA web application designed to assist policymakers in predicting potential rice\nproduction based on specific conditions and parameters.\nOne of the developers responsible for data collection, disaggregation, and\npreprocessing to train the hybrid model used for generating predictions.\nJan 2023 - May 2023\nIris Chat App\nA cloud-based messenger application developed using C# for the front end\nand Microsoft Azure SQL for the back end.\nOne of the developers responsible for building the chat system and deploying\nthe integration between the application and the database.\nFeb 2024 - Dec 2024\nAUF Barangay EMR\nAn Electronic Medical Record system designed to automate, streamline, and\norganize medical data.\nCo-developer of the system, including the implementation of an online form\nthat can be converted into a printed copy in compliance with Department of\nHealth (DOH) standards.\nSUMMARY\nI am a fourth-year Computer Science Undergraduate specializing in Data Science at\nAngeles University Foundation. Over the course of my college undertaking, I\ndeveloped a deep understanding in data engineering, data analysis, AI integration\nthrough machine learning and deep learning.\narcega.lanceangelo@outlook.com | 918-640-9091 | City of San Fernando, Pampanga, Philippines \nhttps://www.linkedin.com/in/lance-angelo-arcega/\nGestura OS\nSep 2025 - Oct 2025\nDeveloped an application that uses computer vision to control the cursor\nthrough hand gestures, utilizing a camera to detect hand movements and\nperform mouse functions.\nCERTIFICATION AZ900 Azure Fundamentals\nCredential ID: A7F24A89104ADE05'),
#  Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-11-19T21:22:00+08:00', 'source': '..\\data\\pdf_files\\Jansen_Cruz_CV.pdf', 'file_path': '..\\data\\pdf_files\\Jansen_Cruz_CV.pdf', 'total_pages': 1, 'format': 'PDF 1.7', 'title': '', 'author': 'JANSEN  CRUZ', 'subject': '', 'keywords': '', 'moddate': '2025-11-19T21:22:00+08:00', 'trapped': '', 'modDate': "D:20251119212200+08'00'", 'creationDate': "D:20251119212200+08'00'", 'page': 0}, page_content='JANSEN C. CRUZ \njansen.c.cruz@gmail.com | LinkedIn | GitHub | +63-921-723-8199 \nEDUCATION \nAngeles University Foundation – BS Computer Science  \n \n \n \n \n \n2022 - 2026 \nUniversity Scholar (President’s Lister), BYA Scholar, Ranked 1st in Program (2022 – Present) \nRelevant Coursework: Artificial Intelligence, Machine Learning, Data Science, Software Engineering \nSTI College Angeles – IT in Mobile App and Web Development \n \n \n \n \n2020 - 2022 \nRanked 3rd in the graduating batch \n \nPROJECTS \nLicense Plate AI Deblurring – AI/ML Engineer, Backend Developer | Thesis   \n             July 2025 – Oct 2025 \n• \nDesigned and trained deep learning models achieving 96.2% accuracy in distortion classification \n(CNN) and 90% accuracy license plate recognition (CRNN), enhancing the reliability and \neffectiveness of traffic enforcement in low-quality surveillance conditions. \n• \nDeveloped 4x distortion-specific GANs using Residual Attention U-Net architectures that restored \nimage quality by up to 84% (SSIM), effectively reducing motion blur, low-light artifacts, and \ncompression noise critical for real-world Philippines license recognition. \n• \nOptimized end-to-end pipeline performance to achieve real-time processing speeds of  \n1.57s (GPU) / 2.42s (CPU), enabling practical deployment on resource-constrained devices.  \nLoan Management System – Full-stack Developer | Freelance \n  \n        \n           Aug 2025 – Sept 2025 \n• \nEngineered a scalable financial web application using C# ASP.NET Core, MSSQL, and Entity \nFramework Core, applying Clean Architecture and CQRS patterns for high maintainability. \n• \nDelivered end-to-end features including loan, borrower, and branch management with automated \npayment tracking and real-time KPI dashboards with interactive charts for actionable insights. \n• \nReplaced manual Excel tracking with a secure, automated solution featuring role-based and real-time \ncustomer tracking, reducing operational overhead by ~70%. \n• \nReceived positive client validation: “Files are secure and customer tracking is effortless.” \nBrgy. Ninoy Aquino EMR – Full-stack Developer, Project Lead | Community Project                Feb 2024 – Dec 2024 \n• \nSpearheaded a 5-member team to develop, deploy, and maintain a healthcare management system \nusing C#, ASP.NET Core, Entity Framework Core, and MySQL, implementing MVC architecture to \nreplace disorganized paper records and eliminate data loss risks.  \n• \nDeveloped data analytics dashboards transforming raw health data into actionable insights using \nreal-time visualizations, enabling evidence-based decision making for midwives. \n• \nIntegrated FINDRISC-based diabetes risk assessment module; validated through CSUQ surveys \nwith a near-perfect usability score (mean = 1.06, where 1.00 is best) and “Best Imaginable” ratings \nacross all dimensions – information quality, interface quality, and overall usability.  \n \nCERTIFICATIONS \nMicrosoft AZ-900: Azure Fundamentals \n \n \n \n \n \n \n \n    May 2025 \nIT Specialist – Cloud Computing \n \n \n \n \n \n \n                     \n     Oct 2025 \nOracle Cloud Infrastructure: AI Foundations Associate \n \n \n \n        \n            \n     Oct 2025 \nOracle Cloud Infrastructure: Generative AI Professional \n \n \n \n       \n            \n     Oct 2025 \n \nTECHNICAL SKILLS  \nLanguages: Python, C#, JavaScript, Java, Dart, SQL, HTML, CSS \nFrameworks: PyTorch, TensorFlow / Keras, L ...
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-11-11T07:39:53+00:00', 'source': '..\\data\\pdf_files\\magno_rianne_cv.pdf', 'file_path': '..\\data\\pdf_files\\magno_rianne_cv.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'magno_rianne_cv', 'author': 'RIANNE LOUISA MAGNO', 'subject': '', 'keywords': 'DAG4RiqMAhw,BAELsaA9Bs4,0', 'moddate': '2025-11-11T07:39:53+00:00', 'trapped': '', 'modDate': "D:20251111073953+00'00'", 'creationDate': "D:20251111073953+00'00'", 'page': 0}, page_content='Languages: Python, C#, JavaScript, Java, Dart, SQL, HTML, CSS\nFrameworks & Libraries: TensorFlow / Keras, Tailwind\nData & Analytics: Power BI, Anaconda, Jupyter\nDeveloper Tools: Git, GitHub Visual Studio Code, Visual Studio, Hugging Face\nDesign/Prototyping Tools: Figma, Balsamiq\nFourth-Year Computer Science Undergraduate specializing in Data Science. Proven ability to\ndevelop data-driven solutions, excelling in analytics and Al integration (Python, SQL, Power BI), and\nprototyping (Figma). Experienced in applying technical knowledge across different platforms,\nincluding mobile development (Flutter) and web development (JavaScript) projects.\nmagnolouisa@gmail.com |  LinkedIn | GitHub | +63-992-802-3247\nRIANNE LOUISA R. MAGNO\n2022 – 2026\nAngeles University Foundation – BS Computer Science\nRanked 4  in Program (Second Semester of Academic Year 2023-2024)\nth\nRanked 2  in Program (First Semester of Academic Year 2024-2025)\nnd\nRelevant coursework: Data Science & Analytics, Artificial Intelligence, and Software Development\nEDUCATION\nTECHNICAL SKILLS\nSUMMARY\nJuly 2025 – October 2025\nRTAverse – Frontend Developer | Thesis\nDeveloped a secure, machine learning-based forecasting system for road traffic accidents,\nutilizing Python (XGBoost) for prediction and providing local authorities with proactive, data-\ndriven safety insights.\nLed the frontend development of the interactive web application using HTML, JavaScript, and\nFolium to create the Interactive Hotspot Map that dynamically visualizes forecasted accident-\nprone areas with color-coding based on risk level.\nBuilt and maintained the high-fidelity Analytical Dashboard interface, integrating its interactive\ncomponents and API endpoint communication to display complex data trends (e.g., high-risk\ntimes, demographics) and ensure functional user interaction.\nPROJECTS\n Nov 2024 – Dec 2024\nDoseKo – Mobile UI/UX Developer | Mobile Application Development\nDeveloped a comprehensive mobile health application utilizing Dart/Flutter for cross-platform\ndeployment, designed to help users manage medications, track side effects, and schedule\nmedical appointments.\nArchitected and implemented the entire user interface and experience (UI/UX), focusing on\nusability and clarity across critical modules, including a simple 3-step onboarding flow, secure\nauthentication, and the user-friendly Medication Management schedule.\nDesigned and executed the presentation layer for the core features, including the full-\ncalendar view for Appointment Scheduling, the intuitive Activity Logging interface for tracking\nsymptoms, and the centralized Profile Hub for updating personal and health metrics.'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-11-05T13:24:14+00:00', 'source': '..\\data\\pdf_files\\PARE_NEOJEZER_CV.pdf', 'file_path': '..\\data\\pdf_files\\PARE_NEOJEZER_CV.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Blue and White Clean and Professional Resume', 'author': 'NEO JEZER  PARE', 'subject': '', 'keywords': 'DAG3uOFZX7M,BAEa-_UscSk,0', 'moddate': '2025-11-05T13:24:14+00:00', 'trapped': '', 'modDate': "D:20251105132414+00'00'", 'creationDate': "D:20251105132414+00'00'", 'page': 0}, page_content='ADDITIONAL INFORMATION\nEDUCATION\nPROJECTS\nDESCRIPTION\nProgramming Languages: Python, Java, C#, JavaScript, Dart, GDScript\nFrameworks & Libraries: Flutter, Node.js, React, TensorFlow, Scikit-learn, NumPy, Pandas,\nMatplotlib, Seaborn, Pygame\nDatabases & Tools: SQL, SQLite, Power BI\nCertifications: OCI AI Foundations, AZ900 Azure Fundamentals\nSeminar: Smarter Analytics: ETL to Dashboard using AI\nSkills: Critical Thinking, Adaptability, Time Management, Collaboration & Teamwork, , System\nDesign, Database Management, Data Visualization\nInterest: Tabletop Games, Video Games, Art, Fitness, Sports\n Aug 2022- present\nBachelor of Science in Computer Science Major in Data Science\nRelevant coursework: Machine Learning, Deep Learning, Advanced Statistics, Data\nStructures and Algorithms, Generative AI, Software Engineering, Application\nDevelopment, Data Analysis\nWater-Processing-and-Management-Interface\nAniLytics - Anime Data Analytics using PowerBi\nIris Chat App\nLed the development of a point-of-sale (POS) desktop application for a local water refilling\ncompany using Next.js, improving transaction efficiency and record management.\nDesigned and implemented an interactive user interface integrated with a relational database for\nreal-time sales tracking and inventory updates.\nDeveloped an interactive analytics dashboard in Power BI to visualize anime ratings, genres, and\npopularity trends.\nPerformed data cleaning, transformation, and modeling using Power Query and custom DAX\nDeveloped a real-time chat application in C#, implementing both frontend and backend\nfunctionality.\nBuilt client–server communication logic, message handling, and responsive user interface.\nNutriSnap: Mobile-Based Food Recognition with Caloric and Macronutrient estimation using\nMobileNetv2 and Yolov8n\nLed development of a mobile-based food recognition system using YOLOv8n (object detection)\nand MobileNetV2 (image classification).\nIntegrated models into a Flutter application with TensorFlow Lite for real-time on-device\ninference.\nI am a fourth-year BS Computer Science major in Data Science student at Angeles University Foundation,\nwith practical experience in machine learning and software development. Through various academic and\nindependent projects, I have developed strong skills in data analysis, and deep learning model training,\ncomplemented by effective communication and problem-solving abilities. I aim to leverage my analytical\nskills and technical expertise to contribute to data-driven initiatives and gain meaningful industry\nexperience.\nNeo Jezer A. Pare\n0949 829 2389\npare.neojezer@gmail.com | pare.neojezer@student.auf.edu.ph\nAngeles City, Pampanga, Philippines\nhttps://www.linkedin.com/in/neo-jezer-pare/'),
#  Document(metadata={'producer': 'Canva', 'creator': 'Canva', 'creationdate': '2025-11-12T05:57:38+00:00', 'source': '..\\data\\pdf_files\\Velasquez_MarcVictor_CV.pdf', 'file_path': '..\\data\\pdf_files\\Velasquez_MarcVictor_CV.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': 'Velasquez_MarcVictor_CV', 'author': 'Marc Velasquez', 'subject': '', 'keywords': 'DAG4dJ8XJ9U,BAGdNEdgg7g,0', 'moddate': '2025-11-12T05:57:38+00:00', 'trapped': '', 'modDate': "D:20251112055738+00'00'", 'creationDate': "D:20251112055738+00'00'", 'page': 0}, page_content="Certifications: Microsoft Certified: Azure Fundamentals, Microsoft Certified: Azure AI\nFundamentals, Microsoft Certified: Azure Data Fundamentals, Oracle Cloud Infrastructure 2025 AI\nFoundations Associate, and Oracle Cloud Infrastructure 2025 Certified AI Professional.\nAwards/Activities: College Scholar (2023 - 2024), AUF JPCS Digital Solution Hackathon 2025\n(3  Place)\nrd\n2022 - 2026\nBachelor of Science in Computer Science\nAngeles University Foundation\nRelevant coursework in machine learning, deep learning, advanced statistics, data structures and\nalgorithms, generative AI, software development and engineering, and data analysis\nI am a 4th year Computer Science student at Angeles University Foundation, specializing in Data\nScience. Experienced with AI model development, cloud computing, and data analysis as well as  \nproficient in C++, C#/.NET, Python, Java, and Rust. I hold certifications in Microsoft Azure and\nOracle Cloud Infrastructure, focusing on impactful solutions for real-world issues.\nMARC VICTOR L. VELASQUEZ\n(+63)923-450-5225 | Angeles City, Pampanga, Philippines |  velasquezmarcvictor@gmail.com\nhttps://www.linkedin.com/in/mrcvctr-vel\nJan 2023 - Present\nApplication Developer (Freelance)\nDeveloped and deployed web applications to enhance clients' workflows, leading to increased\nefficiency.\nSuccessfully launched clients' applications on Amazon Web Services or Microsoft Azure,\ndepending on their preference, ensuring robust performance and scalability.\nEXPERIENCE\nEDUCATION\nADDITIONAL INFORMATION\nDESCRIPTION\nJan 2025 - Present\nUnrealLogic: A Text-to-Logic Model Transformer for Generating Actor\nBehaviors in Unreal Engine Simulations\nDeveloping an AI Director system in Unreal Engine 5 that enables dynamic, physics-driven actor\nbehaviors based on text prompts, utilizing a diffusion and large language model pipeline.  \nModifying the core C++ source code of Unreal Engine 5 to facilitate the AI system pipeline.\nPROJECTS\nApr 2025 - Oct 2025\nJointWise: A Knee Tear Detection of the Anterior Cruciate Ligament and\nMeniscus from MRI Data using Stacking Ensemble Learning\nDeveloped a YOLOv11 ensemble pipeline to detect ACL and meniscus tears with fastMRI data.  \nCreated a web app for patient records to show model results to healthcare professionals.\nJan 2024 - May 2024\nWater Management and Processing Web Application\nA web application was created using Next.js for client and server operations and Express.js to\nconnect with a PostgreSQL database for managing water refilling business records.\nLanguages: C++, Python, C#, Java, Rust, HTML, CSS, JavaScript, and Go\nFrameworks: PyTorch, Tensorflow, Next.js, React Native, and Flutter\nTools: Git, Visual Studio, Visual Studio Code, GitHub Desktop, HuggingFace, Power BI, Microsoft\nFabric, Amazon Web Services, Microsoft Azure, and AppWrite\nSKILLS")]
